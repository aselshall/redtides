# %%
pip install copernicusmarine
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 18.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 3.8/3.8 MB 28.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 27.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/13.4 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/13.4 MB 29.1 MB/s eta 0:00:01
#    ---------------------------------------- 13.4/13.4 MB 32.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/836.8 kB ? eta -:--:--
#    --------------------------------------- 836.8/836.8 kB 35.9 MB/s eta 0:00:00
# ...
